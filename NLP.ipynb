# %% [markdown]
# <a href="https://colab.research.google.com/github/atharvakadam-7/notebook/blob/main/NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk
# natural language toolkit
# textual data

# %%
text = """Code Geass: Lelouch of the Rebellion (Japanese: コードギアス 反逆のルルーシュ, Hepburn: Kōdo Giasu: Hangyaku no Rurūshu), often referred to simply as Code Geass, is a Japanese anime television series produced by Sunrise. It was directed by Gorō Taniguchi and written by Ichirō Ōkouchi, with original character designs by Clamp. Set in an alternate timeline, it follows the exiled prince Lelouch Lamperouge, who obtains the "power of absolute obedience" from a mysterious woman named C.C. Using this supernatural power, known as Geass, he leads a rebellion against the rule of the Holy Britannian Empire, commanding a series of mecha battles.

Code Geass was broadcast in Japan on MBS from October 2006 to July 2007. Its sequel series, Code Geass: Lelouch of the Rebellion R2, ran as a simulcast on MBS and TBS from April to September 2008. The series has also been adapted into various manga and light novels, with the former showing alternate scenarios from the TV series."""

# %%
from nltk.tokenize import sent_tokenize,word_tokenize

# %%
import nltk
nltk.download('punkt')
import nltk
nltk.download('punkt_tab')
word_tokens = word_tokenize(text)
word_tokens
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['Code',
#  'Geass',
#  ':',
#  'Lelouch',
#  'of',
#  'the',
#  'Rebellion',
#  '(',
#  'Japanese',
#  ':',
#  'コードギアス',
#  '反逆のルルーシュ',
#  ',',
#  'Hepburn',
#  ':',
#  'Kōdo',
#  'Giasu',
#  ':',
#  'Hangyaku',
#  'no',
#  'Rurūshu',
#  ')',
#  ',',
#  'often',
#  'referred',
#  'to',
#  'simply',
#  'as',
#  'Code',
#  'Geass',
#  ',',
#  'is',
#  'a',
#  'Japanese',
#  'anime',
#  'television',
#  'series',
#  'produced',
#  'by',
#  'Sunrise',
#  '.',
#  'It',
#  'was',
#  'directed',
#  'by',
#  'Gorō',
#  'Taniguchi',
#  'and',
#  'written',
#  'by',
#  'Ichirō',
#  'Ōkouchi',
#  ',',
#  'with',
#  'original',
#  'character',
#  'designs',
#  'by',
#  'Clamp',
#  '.',
#  'Set',
#  'in',
#  'an',
#  'alternate',
#  'timeline',
#  ',',
#  'it',
# ...

# %%
sent_tokens=sent_tokenize(text)
sent_tokens
# Out:
# ['Code Geass: Lelouch of the Rebellion (Japanese: コードギアス 反逆のルルーシュ, Hepburn: Kōdo Giasu: Hangyaku no Rurūshu), often referred to simply as Code Geass, is a Japanese anime television series produced by Sunrise.',
#  'It was directed by Gorō Taniguchi and written by Ichirō Ōkouchi, with original character designs by Clamp.',
#  'Set in an alternate timeline, it follows the exiled prince Lelouch Lamperouge, who obtains the "power of absolute obedience" from a mysterious woman named C.C.',
#  'Using this supernatural power, known as Geass, he leads a rebellion against the rule of the Holy Britannian Empire, commanding a series of mecha battles.',
#  'Code Geass was broadcast in Japan on MBS from October 2006 to July 2007.',
#  'Its sequel series, Code Geass: Lelouch of the Rebellion R2, ran as a simulcast on MBS and TBS from April to September 2008.',
# ...

# %%
from string import punctuation

# %%
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
text = """Code Geass: Lelouch of the Rebellion (Japanese: コードギアス 反逆のルルーシュ, Hepburn: Kōdo Giasu: Hangyaku no Rurūshu), often referred to simply as Code Geass, is a Japanese anime television series produced by Sunrise. It was directed by Gorō Taniguchi and written by Ichirō Ōkouchi, with original character designs by Clamp. Set in an alternate timeline, it follows the exiled prince Lelouch Lamperouge, who obtains the "power of absolute obedience" from a mysterious woman named C.C. Using this supernatural power, known as Geass, he leads a rebellion against the rule of the Holy Britannian Empire, commanding a series of mecha battles.

Code Geass was broadcast in Japan on MBS from October 2006 to July 2007. Its sequel series, Code Geass: Lelouch of the Rebellion R2, ran as a simulcast on MBS and TBS from April to September 2008. The series has also been adapted into various manga and light novels, with the former showing alternate scenarios from the TV series."""
word_tokens=word_tokenize(text)

# %%
word_tokens
# Out:
# ['Code',
#  'Geass',
#  ':',
#  'Lelouch',
#  'of',
#  'the',
#  'Rebellion',
#  '(',
#  'Japanese',
#  ':',
#  'コードギアス',
#  '反逆のルルーシュ',
#  ',',
#  'Hepburn',
#  ':',
#  'Kōdo',
#  'Giasu',
#  ':',
#  'Hangyaku',
#  'no',
#  'Rurūshu',
#  ')',
#  ',',
#  'often',
#  'referred',
#  'to',
#  'simply',
#  'as',
#  'Code',
#  'Geass',
#  ',',
#  'is',
#  'a',
#  'Japanese',
#  'anime',
#  'television',
#  'series',
#  'produced',
#  'by',
#  'Sunrise',
#  '.',
#  'It',
#  'was',
#  'directed',
#  'by',
#  'Gorō',
#  'Taniguchi',
#  'and',
#  'written',
#  'by',
#  'Ichirō',
#  'Ōkouchi',
#  ',',
#  'with',
#  'original',
#  'character',
#  'designs',
#  'by',
#  'Clamp',
#  '.',
#  'Set',
#  'in',
#  'an',
#  'alternate',
#  'timeline',
#  ',',
#  'it',
#  'follows',
#  'the',
#  'exiled',
#  'prince',
#  'Lelouch',
#  'Lamperouge',
#  ',',
#  'who',
#  'obtains',
#  'the',
#  '``',
#  'power',
#  'of',
#  'absolute',
#  'obedience',
#  "''",
#  'from',
#  'a',
#  'mysterious',
# ...

# %%
a=[1,2,3,4,15]
1 not in a #membership operator
# Out:
# False

# %%
clean_data=[i for i in word_tokens if i not in punctuation ]
clean_data
# Out:
# ['Code',
#  'Geass',
#  'Lelouch',
#  'of',
#  'the',
#  'Rebellion',
#  'Japanese',
#  'コードギアス',
#  '反逆のルルーシュ',
#  'Hepburn',
#  'Kōdo',
#  'Giasu',
#  'Hangyaku',
#  'no',
#  'Rurūshu',
#  'often',
#  'referred',
#  'to',
#  'simply',
#  'as',
#  'Code',
#  'Geass',
#  'is',
#  'a',
#  'Japanese',
#  'anime',
#  'television',
#  'series',
#  'produced',
#  'by',
#  'Sunrise',
#  'It',
#  'was',
#  'directed',
#  'by',
#  'Gorō',
#  'Taniguchi',
#  'and',
#  'written',
#  'by',
#  'Ichirō',
#  'Ōkouchi',
#  'with',
#  'original',
#  'character',
#  'designs',
#  'by',
#  'Clamp',
#  'Set',
#  'in',
#  'an',
#  'alternate',
#  'timeline',
#  'it',
#  'follows',
#  'the',
#  'exiled',
#  'prince',
#  'Lelouch',
#  'Lamperouge',
#  'who',
#  'obtains',
#  'the',
#  '``',
#  'power',
#  'of',
#  'absolute',
#  'obedience',
#  "''",
#  'from',
#  'a',
#  'mysterious',
#  'woman',
#  'named',
#  'C.C',
#  'Using',
#  'this',
#  'supernatural',
#  'power',
#  'known',
#  'as',
#  'Geass',
# ...

# %%
clean_data1 = [i for i in sent_tokens if i not in punctuation]
clean_data1
# Out:
# ['Code Geass: Lelouch of the Rebellion (Japanese: コードギアス 反逆のルルーシュ, Hepburn: Kōdo Giasu: Hangyaku no Rurūshu), often referred to simply as Code Geass, is a Japanese anime television series produced by Sunrise.',
#  'It was directed by Gorō Taniguchi and written by Ichirō Ōkouchi, with original character designs by Clamp.',
#  'Set in an alternate timeline, it follows the exiled prince Lelouch Lamperouge, who obtains the "power of absolute obedience" from a mysterious woman named C.C.',
#  'Using this supernatural power, known as Geass, he leads a rebellion against the rule of the Holy Britannian Empire, commanding a series of mecha battles.',
#  'Code Geass was broadcast in Japan on MBS from October 2006 to July 2007.',
#  'Its sequel series, Code Geass: Lelouch of the Rebellion R2, ran as a simulcast on MBS and TBS from April to September 2008.',
# ...

# %%
a = "HiI HoW ArE yOu?"
a.title()
# Out:
# 'Hii How Are You?'

# %%
a.lower()
# Out:
# 'hii how are you?'

# %%
a.upper()
# Out:
# 'HII HOW ARE YOU?'

# %%
a.casefold()
# Out:
# 'hii how are you?'

# %%
a.capitalize()
# Out:
# 'Hii how are you?'

# %%
a.title()
a.capitalize()
# Out:
# 'Hii how are you?'

# %%
print(a.title())
print(a.capitalize())
print(a.lower())
print(a.upper())
# Out:
# Hii How Are You?
# Hii how are you?
# hii how are you?
# HII HOW ARE YOU?

# %%
for i in text:
  a = print(i.upper())
  b = print(i.lower())
  c= i.capitalize()
  d= i.casefold()
# Out:
# C
# c
# O
# o
# D
# d
# E
# e
#
#
# G
# g
# E
# e
# A
# a
# S
# s
# S
# s
# :
# :
#
#
# L
# l
# E
# e
# L
# l
# O
# o
# U
# u
# C
# c
# H
# h
#
#
# O
# o
# F
# f
#
#
# T
# t
# H
# h
# E
# e
#
#
# R
# r
# E
# e
# B
# b
# E
# e
# L
# l
# L
# l
# I
# i
# O
# o
# N
# n
#
#
# (
# (
# J
# j
# A
# a
# P
# p
# A
# a
# N
# n
# E
# e
# S
# s
# E
# e
# :
# :
#
#
# コ
# コ
# ー
# ー
# ド
# ド
# ギ
# ギ
# ア
# ア
# ス
# ス
#
#
# 反
# 反
# 逆
# 逆
# の
# の
# ル
# ル
# ル
# ル
# ー
# ー
# シ
# シ
# ュ
# ュ
# ,
# ,
#
#
# H
# h
# E
# e
# P
# p
# B
# b
# U
# u
# R
# r
# N
# n
# :
# :
#
#
# K
# k
# Ō
# ō
# D
# d
# O
# o
#
#
# G
# g
# I
# i
# A
# a
# S
# s
# U
# u
# :
# :
#
#
# H
# h
# A
# a
# N
# n
# G
# g
# Y
# y
# A
# a
# K
# k
# U
# u
#
#
# N
# n
# O
# o
#
#
# R
# r
# U
# u
# R
# r
# Ū
# ū
# S
# s
# H
# h
# U
# u
# )
# )
# ,
# ,
#
#
# O
# o
# F
# f
# T
# t
# E
# e
# N
# n
#
#
# R
# r
# E
# e
# F
# f
# E
# e
# R
# r
# R
# r
# E
# e
# D
# d
#
#
# T
# t
# O
# o
#
#
# S
# s
# I
# i
# M
# m
# P
# p
# L
# l
# Y
# y
#
#
# A
# a
# S
# ...

# %%
# !pip install stopwords

# %%
# !pip install nltk # Ensure NLTK is installed
from nltk.corpus import stopwords # Import stopwords from NLTK
import nltk
nltk.download('stopwords')
total_count = stopwords.fileids() # Now it can be used
total_count
# Out:
# ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['arabic',
#  'azerbaijani',
#  'basque',
#  'bengali',
#  'catalan',
#  'chinese',
#  'danish',
#  'dutch',
#  'english',
#  'finnish',
#  'french',
#  'german',
#  'greek',
#  'hebrew',
#  'hinglish',
#  'hungarian',
#  'indonesian',
#  'italian',
#  'kazakh',
#  'nepali',
#  'norwegian',
#  'portuguese',
#  'romanian',
#  'russian',
#  'slovene',
#  'spanish',
#  'swedish',
#  'tajik',
#  'turkish']

# %%
stop = stopwords.words("russian")
stop
# Out:
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
#  'тоже',
#  'себе',
#  'под',
#  'будет',
#  'ж',
#  'тогда',
#  'кто',
#  'этот',
#  'того',
#  'потому',
#  'этого',
#  'какой',
#  'совсем',
#  'ним',
#  'здесь',
# ...

# %%
stop = stopwords.words("english")
stop
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...

# %%
stopwords_removed = [i for i in clean_data if i not in stop]
stopwords_removed
# Out:
# ['Code',
#  'Geass',
#  'Lelouch',
#  'Rebellion',
#  'Japanese',
#  'コードギアス',
#  '反逆のルルーシュ',
#  'Hepburn',
#  'Kōdo',
#  'Giasu',
#  'Hangyaku',
#  'Rurūshu',
#  'often',
#  'referred',
#  'simply',
#  'Code',
#  'Geass',
#  'Japanese',
#  'anime',
#  'television',
#  'series',
#  'produced',
#  'Sunrise',
#  'It',
#  'directed',
#  'Gorō',
#  'Taniguchi',
#  'written',
#  'Ichirō',
#  'Ōkouchi',
#  'original',
#  'character',
#  'designs',
#  'Clamp',
#  'Set',
#  'alternate',
#  'timeline',
#  'follows',
#  'exiled',
#  'prince',
#  'Lelouch',
#  'Lamperouge',
#  'obtains',
#  '``',
#  'power',
#  'absolute',
#  'obedience',
#  "''",
#  'mysterious',
#  'woman',
#  'named',
#  'C.C',
#  'Using',
#  'supernatural',
#  'power',
#  'known',
#  'Geass',
#  'leads',
#  'rebellion',
#  'rule',
#  'Holy',
#  'Britannian',
#  'Empire',
#  'commanding',
#  'series',
#  'mecha',
#  'battles',
#  'Code',
#  'Geass',
#  'broadcast',
#  'Japan',
#  'MBS',
#  'October',
#  '2006',
#  'July',
# ...

# %%
from nltk.stem import LancasterStemmer,WordNetLemmatizer

# %%
stemming = LancasterStemmer()

for i in stopwords_removed:
  print(stemming.stem(i))
  print (text)
# Out:
# cod
# Code Geass: Lelouch of the Rebellion (Japanese: コードギアス 反逆のルルーシュ, Hepburn: Kōdo Giasu: Hangyaku no Rurūshu), often referred to simply as Code Geass, is a Japanese anime television series produced by Sunrise. It was directed by Gorō Taniguchi and written by Ichirō Ōkouchi, with original character designs by Clamp. Set in an alternate timeline, it follows the exiled prince Lelouch Lamperouge, who obtains the "power of absolute obedience" from a mysterious woman named C.C. Using this supernatural power, known as Geass, he leads a rebellion against the rule of the Holy Britannian Empire, commanding a series of mecha battles.
#
# Code Geass was broadcast in Japan on MBS from October 2006 to July 2007. Its sequel series, Code Geass: Lelouch of the Rebellion R2, ran as a simulcast on MBS and TBS from April to September 2008. The series has also been adapted into various manga and light novels, with the former showing alternate scenarios from the TV series.
# geass
# ...

# %%
import nltk
nltk.download('wordnet')
lemma = WordNetLemmatizer()
for i in stopwords_removed:
  text = print(lemma.lemmatize(i,pos='v'))
  print(text, end = "")
# Out:
# Code
# NoneGeass
# NoneLelouch
# NoneRebellion
# NoneJapanese
# Noneコードギアス
# None反逆のルルーシュ
# NoneHepburn
# NoneKōdo
# NoneGiasu
# NoneHangyaku
# NoneRurūshu
# Noneoften
# Nonerefer
# Nonesimply
# NoneCode
# NoneGeass
# NoneJapanese
# Noneanime
# Nonetelevision
# Noneseries
# Noneproduce
# NoneSunrise
# NoneIt
# Nonedirect
# NoneGorō
# NoneTaniguchi
# Nonewrite
# NoneIchirō
# NoneŌkouchi
# Noneoriginal
# Nonecharacter
# Nonedesign
# NoneClamp
# NoneSet
# Nonealternate
# Nonetimeline
# Nonefollow
# Noneexile
# Noneprince
# NoneLelouch
# NoneLamperouge
# Noneobtain
# None``
# Nonepower
# Noneabsolute
# Noneobedience
# None''
# Nonemysterious
# Nonewoman
# Nonename
# NoneC.C
# NoneUsing
# Nonesupernatural
# Nonepower
# Noneknow
# NoneGeass
# Nonelead
# Nonerebellion
# Nonerule
# NoneHoly
# NoneBritannian
# NoneEmpire
# Nonecommand
# Noneseries
# Nonemecha
# Nonebattle
# NoneCode
# NoneGeass
# Nonebroadcast
# NoneJapan
# NoneMBS
# NoneOctober
# None2006
# NoneJuly
# None2007
# NoneIts
# ...

# %%
# !pip install wordcloud

# %%
pip install wikipedia
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11679 sha256=e37b877418d0cecbb11cf4e82500bd14889124a3307b17ec48d9a61550ae13cb
#   Stored in directory: /root/.cache/pip/wheels/8f/ab/cb/45ccc40522d3a1c41e1d2ad53b8f33a62f394011ec38cd71c6
# Successfully built wikipedia
# ...

# %%
import wikipedia
results = wikipedia.page("Cristiano Ronaldo")
final_result = results.content
print(final_result)
# Out:
# Cristiano Ronaldo dos Santos Aveiro  (Portuguese pronunciation: [kɾiʃˈtjɐnu ʁɔˈnaldu] ; born 5 February 1985) is a Portuguese professional footballer who plays as a forward for and captains both the Saudi Pro League club Al Nassr and the Portugal national team. Widely regarded as one of the greatest players of all time, Ronaldo has won numerous individual accolades throughout his career, such as five Ballon d'Or awards, a record three UEFA Men's Player of the Year Awards, four European Golden Shoes, and was named five times the world's best player by FIFA, the most by a European player. He has won 33 trophies in his career, including seven league titles, five UEFA Champions Leagues, the UEFA European Championship and the UEFA Nations League. Ronaldo holds the records for most appearances (183), goals (140) and assists (42) in the Champions League, most appearances (30), assists (8), goals in the European Championship (14), international appearances (217) and international goals (135)
# ...

# %%
results = wikipedia.summary("Cristiano Ronaldo",sentences=7)
print(results)
# Out:
# Cristiano Ronaldo dos Santos Aveiro  (Portuguese pronunciation: [kɾiʃˈtjɐnu ʁɔˈnaldu] ; born 5 February 1985) is a Portuguese professional footballer who plays as a forward for and captains both the Saudi Pro League club Al Nassr and the Portugal national team. Widely regarded as one of the greatest players of all time, Ronaldo has won numerous individual accolades throughout his career, such as five Ballon d'Or awards, a record three UEFA Men's Player of the Year Awards, four European Golden Shoes, and was named five times the world's best player by FIFA, the most by a European player. He has won 33 trophies in his career, including seven league titles, five UEFA Champions Leagues, the UEFA European Championship and the UEFA Nations League. Ronaldo holds the records for most appearances (183), goals (140) and assists (42) in the Champions League, most appearances (30), assists (8), goals in the European Championship (14), international appearances (217) and international goals (135)
# ...

# %%
results = wikipedia.summary("Lionel Messi (footballer)",sentences=7)
print(results)
# Out:
# The Messi–Ronaldo rivalry, or Ronaldo–Messi rivalry, is a sporting rivalry in football propelled by the media and fans that involves Argentine footballer Lionel Messi and Portuguese footballer Cristiano Ronaldo, mainly for being contemporaries and due to their similar records and sporting successes. They spent nine seasons in the prime of their careers facing off regularly while playing for rival clubs Barcelona and Real Madrid.
# Together, they have achieved various historical milestones, coming to be considered as two of the best footballers of all time. They are two of the most decorated players ever, having won 77 official trophies in total (Messi 44, Ronaldo 33) during their senior careers thus far, and have regularly broken the 50-goal barrier in a single season. According to IFFHS, they are the only two players to score over 800 goals each in their careers for club and country. Ronaldo holds the record for most official goals in a career.
# ...

# %%
import os
import wordcloud
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

wordcloud = WordCloud(width=800, height=800,
                      background_color='white',
                      stopwords=set(STOPWORDS),
                      min_font_size=10).generate(final_result)

def plot_cloud(wordcloud):
    plt.figure(figsize=(40,30))
    plt.imshow(wordcloud)
    plt.axis("off");

plot_cloud(wordcloud)
